# %%
import pandas as pd 
import matplotlib.pyplot as plt
from google.colab import drive

# %%
drive.mount('/content/gdrive/', force_remount= True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv('/content/gdrive/MyDrive/google colab/447_project_data_fixed.csv', parse_dates= True, index_col='Date')

# %%
plt.figure(figsize=(12,6), dpi = 150)

plt.plot(df['Close'])
plt.ylabel('exchange rate $/euro')
plt.xlabel('date')
plt.title('USD/Euro Exchange Rate')
# Out:
# Text(0.5, 1.0, 'USD/Euro Exchange Rate')

# %% [markdown]
# ## Exchange Rate for USD/Euro
